# %% [markdown]
# ## Задача 1
#
# Посчитайте среднее время жизни пользователей, которые выставили более 100 оценок. Под временем жизни понимается разница между максимальным и минимальным значением столбца timestamp для данного значения userId

# %%
import pandas as pd

# %%
df_ratings = pd.read_csv('ratings.csv')
df_ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
ratings_grouped = df_ratings.groupby('userId').count()
ratings_grouped.head()
# Out:
#         movieId  rating  timestamp
# userId
# 1            20      20         20
# 2            76      76         76
# 3            51      51         51
# 4           204     204        204
# 5           100     100        100

# %%
ratings_filtered = ratings_grouped[ratings_grouped.movieId >= 100].sort_values('movieId')
ratings_filtered.head()
# Out:
#         movieId  rating  timestamp
# userId
# 188         100     100        100
# 160         100     100        100
# 370         100     100        100
# 560         100     100        100
# 5           100     100        100

# %% [markdown]
# ## Задача 2

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)
rzd
# Out:
#    client_id  rzd_revenue
# 0        111         1093
# 1        112         2810
# 2        113        10283
# 3        114         5774
# 4        115          981

# %%
auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)
auto
# Out:
#    client_id  auto_revenue
# 0        113         57483
# 1        114            83
# 2        115           912
# 3        116          4834
# 4        117            98

# %%
air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)
air
# Out:
#    client_id  air_revenue
# 0        115           81
# 1        116            4
# 2        117           13
# 3        118          173

# %%
client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1', 
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)
client_base
# Out:
#    client_id          address
# 0        111  Комсомольская 4
# 1        112   Энтузиастов 8а
# 2        113  Левобережная 1а
# 3        114          Мира 14
# 4        115        ЗЖБИиДК 1
# 5        116    Строителей 18
# 6        117  Панфиловская 33
# 7        118     Мастеркова 4

# %%
total = client_base.merge(auto, how = 'left').merge(air, how = 'left').merge(rzd, how = 'left')
total_1 = total.drop(['address'], axis=1)
total_1
# Out:
#    client_id  auto_revenue  air_revenue  rzd_revenue
# 0        111           NaN          NaN       1093.0
# 1        112           NaN          NaN       2810.0
# 2        113       57483.0          NaN      10283.0
# 3        114          83.0          NaN       5774.0
# 4        115         912.0         81.0        981.0
# 5        116        4834.0          4.0          NaN
# 6        117          98.0         13.0          NaN
# 7        118           NaN        173.0          NaN

# %%
total
# Out:
#    client_id          address  auto_revenue  air_revenue  rzd_revenue
# 0        111  Комсомольская 4           NaN          NaN       1093.0
# 1        112   Энтузиастов 8а           NaN          NaN       2810.0
# 2        113  Левобережная 1а       57483.0          NaN      10283.0
# 3        114          Мира 14          83.0          NaN       5774.0
# 4        115        ЗЖБИиДК 1         912.0         81.0        981.0
# 5        116    Строителей 18        4834.0          4.0          NaN
# 6        117  Панфиловская 33          98.0         13.0          NaN
# 7        118     Мастеркова 4           NaN        173.0          NaN

# %% [markdown]
# ## Задача 3

# %% [markdown]
# В задаче сквозной аналитики вам предоставили данные по местоположению пользователей. Т. е. для каждого user_id известна последовательность координат (широта/долгота), когда они требовались приложению для полноценной работы. Как бы вы добавили эти сведения в таблицу визитов и покупок?

# %%
purchases = pd.DataFrame(
    {
        'user_id': [11, 22, 55, 11, 99],
        'category': ['Спорт', 'Авто', 'Дача', 'Спорт', 'Авто'],
    }
)

purchases = purchases[['user_id', 'category']]
purchases
# Out:
#    user_id category
# 0       11    Спорт
# 1       22     Авто
# 2       55     Дача
# 3       11    Спорт
# 4       99     Авто
