# %%
import numpy as np
import pandas as pd  

from sklearn import linear_model
from sklearn.model_selection import train_test_split


from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression

from sklearn.datasets import load_boston
#df_boston = load_boston()
df_boston = pd.read_csv(load_boston()['filename'], skiprows=1)
df_boston
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
#инфо про датасет
#print(load_boston()['DESCR'])

# %% [markdown]
#  CRIM - уровень преступности на душу населения
#  ZN - доля жилой земли
#  INDUS  - доля неторговой площади на город
#  CHAS -?
#  NOX - концентрация окиси озота
#  RM - среднее кол-во комнат в доме
# AGE - домовладельцы, доля
# DIS - расстояние до 5 центров зантости
# RAD - индекс доступности к магистралям
# TAX - ставка налога на имущество
# PTRATIO  - соотноение ученик-учитель
# B - доля чернокожего населения
# LSTAT - более низвий статус населения
# MEDV - средняя стоимость домов

# %% [markdown]
# Разделим нам Датасет на 2. В одном будут значения всех столбцов, а в другом наша целевая стоимость

# %%
X = pd.DataFrame(df_boston.data, columns = df_boston.feature_names)
Y = pd.DataFrame(df_boston.target)
#print(X)
#print(Y)

# %%
reg = linear_model.LinearRegression()

# %% [markdown]
# разделим наши данные на тренировочные и тестовые в соотношении 80%/20%

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.2, random_state=30)

# %%
#обучаем модель
reg.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# посмотрим на веса, которые подобрала наша модель для каждого из параметров

# %%
print(reg.coef_)
# Out:
# [[-1.10214967e-01  4.10654046e-02  1.80366661e-02  3.24554801e+00
#   -1.87109384e+01  3.74450628e+00  5.71160169e-03 -1.52545323e+00
#    3.21188947e-01 -1.33423934e-02 -9.77173081e-01  7.35729616e-03
#   -5.61078681e-01]]

# %% [markdown]
# выведем прогнощируемые цены

# %%
y_pred = reg.predict(x_test)
print(y_pred)
# Out:
# [[17.59214096]
#  [12.15925358]
#  [20.24493634]
#  [31.70438829]
#  [15.56974618]
#  [18.07790121]
#  [19.41835551]
#  [41.12726209]
#  [15.09083312]
#  [24.57970988]
#  [19.94850954]
#  [32.83617213]
#  [20.9263881 ]
#  [30.09870192]
#  [13.3835526 ]
#  [23.72238559]
#  [13.29193631]
#  [28.00168378]
#  [15.36251697]
#  [27.26868887]
#  [20.85163137]
#  [17.29562123]
#  [30.81315727]
#  [12.94906374]
#  [15.28636367]
#  [16.62504973]
#  [18.19266159]
#  [-0.0955886 ]
#  [13.21749982]
#  [13.38361014]
#  [16.89398118]
#  [23.73298773]
#  [32.97355014]
#  [28.61090574]
#  [19.49709411]
#  [22.11673415]
#  [11.90117186]
#  [22.93950739]
#  [20.27896966]
#  [19.94458935]
#  [18.18458752]
#  [20.56337562]
#  [40.5801841 ]
#  [24.06166928]
#  [26.73541   ]
#  [20.51426231]
#  [22.12644218]
#  [17.62326688]
#  [18.39028931]
#  [15.50987528]
#  [15.51439149]
#  [18.18340375]
#  [18.90675781]
#  [25.29267483]
#  [31.49323693]
#  [23.38157202]
#  [37.52037151]
#  [25.63603971]
# ...

# %% [markdown]
# фактическая цена домов

# %%
y_test[0]
# Out:
# 21     19.6
# 440    10.5
# 103    19.3
# 178    29.9
# 22     15.2
# 31     14.5
# 286    20.1
# 282    46.0
# 424    11.7
# 100    27.5
# 351    24.1
# 307    28.2
# 155    15.6
# 0      24.0
# 138    13.3
# 249    26.2
# 435    13.4
# 181    36.2
# 26     16.6
# 90     22.6
# 67     22.0
# 411    17.2
# 236    25.1
# 245    18.5
# 378    13.1
# 468    19.1
# 317    19.8
# 374    13.8
# 457    13.5
# 408    17.2
#        ...
# 110    21.7
# 296    27.1
# 158    24.3
# 205    22.6
# 373    13.8
# 167    23.8
# 242    22.2
# 220    26.7
# 422    20.8
# 164    22.7
# 92     22.9
# 212    22.4
# 42     25.3
# 276    33.2
# 202    42.3
# 353    30.1
# 221    21.7
# 451    15.2
# 349    26.6
# 235    24.0
# 128    18.0
# 344    31.2
# 147    14.6
# 244    17.6
# 141    14.4
# 3      33.4
# 323    18.5
# 41     26.6
# 208    24.4
# 442    18.4
# Name: 0, Length: 102, dtype: float64

# %%
print('Error: {}'.format(mean_absolute_error(y_pred, y_test)))
# Out:
# Error: 3.2254104069762963
