# %% [markdown]
# ## зачада 1

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/administrator/Documents/нетология/python для анализа данных/лекция 6. 19.08/ml-20m/ratings.csv')
data.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
data.loc[data['rating'] == 5.0].head()
# Out:
#      userId  movieId  rating   timestamp
# 131       1     4993     5.0  1112484682
# 142       1     5952     5.0  1112484619
# 158       1     7153     5.0  1112484633
# 170       1     8507     5.0  1094786027
# 176       2       62     5.0   974820598

# %%
len(data.loc[data['rating'] == 5.0])
# Out:
# 2898660

# %% [markdown]
# ## зачада 2
#
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
data2 = pd.read_csv('power.csv')
data2.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
countries_baltic = data2[ ((data2['country'] == 'Latvia') | (data2['country'] == 'Lithuania') | (data2['country'] == 'Estonia')) & ((data2['category'] == 4) | (data2['category'] == 12) | (data2['category'] == 21)) & (data['year'] >= 2005) & (data['year'] <= 2010) & (data['quantity'] > 0)]
countries_baltic.head()
# Out:
#           country  year  quantity  category
# 10617     Estonia  2008       1.0         4
# 10620     Estonia  2005       1.0         4
# 11156   Lithuania  2008       1.0         4
# 11158   Lithuania  2006       1.0         4
# 11159   Lithuania  2005       1.0         4
# 12755     Estonia  2008       1.0         4
# 12758     Estonia  2005       1.0         4
# 13294   Lithuania  2008       1.0         4
# 13296   Lithuania  2006       1.0         4
# 13297   Lithuania  2005       1.0         4
# 15525     Estonia  2008       1.0         4
# 15528     Estonia  2005       1.0         4
# 16068   Lithuania  2008       1.0         4
# 16070   Lithuania  2006       1.0         4
# 16071   Lithuania  2005       1.0         4
# 17675     Estonia  2008       1.0         4
# 17678     Estonia  2005       1.0         4
# 18218   Lithuania  2008       1.0         4
# 18220   Lithuania  2006       1.0         4
# 18221   Lithuania  2005       1.0         4
# ...

# %%
sum = countries_baltic.quantity.sum()
#print(len(countries_baltic.quantity))
print(sum)
# Out:
# 347
# 240580.0

# %% [markdown]
# ## задача 3

# %%
pd.read_html('http://traviko.ru/article/pogoda-na-kurortah-mira-po-mesyacam-svodnaya-tablica-temperatury-i-sezonov-dojdey')[1]
# Out:
#        Страна  Янв.  Фев.  Март  Апр.  Май  Июнь  Июль  Август  Сент.  Окт.  \
# 0     Таиланд    27    28    29    29   30    29    29      29     28    27
# 1      Турция    15    17    18    18   21    24    28      29     28    25
# 2        Куба    25    25    25    26   27    28    29      30     29    28
# 3       Тунис    14    15    14    16   19    22    26      27     25    24
# 4       Индия    27    27    27    28   29    28    27      27     27    28
# 5     Вьетнам    24    24    26    27   28    28    28      28     29    28
# 6   Индонезия    28    28    29    28   28    29    28      27     28    28
# 7   Шри-Ланка    27    28    29    29   28    27    27      27     28    28
# 8         ОАЭ    22    21    22    26   29    31    33      33     32    31
# 9    Малайзия    27    27    28    29   30    29    29      29     29    29
# 10     Греция    16    16    17    19   19    22    25      26     25    23
# ...
